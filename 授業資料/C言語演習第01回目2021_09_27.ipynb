# %% [markdown]
# <a href="https://colab.research.google.com/github/ttnok/c-programming-on-colab/blob/main/%E6%8E%88%E6%A5%AD%E8%B3%87%E6%96%99/C%E8%A8%80%E8%AA%9E%E6%BC%94%E7%BF%92%E7%AC%AC01%E5%9B%9E%E7%9B%AE2021_09_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # C 言語演習 第 1 回
# 2021-09-27
#
#
# ※ このページへは Google Chrome か Microsoft Edge でアクセスしてください。
# 他のブラウザでも動作する場合がありますが、この授業ではサポートしません。
#
# ※ まだこのノートブックは授業時に各自が演習を行った後、提出することになります。
#
# ## 内容
# 1. Colab ノートブックを「ドライブにコピー」
# 2. 「Colab Notebooks」フォルダの確認
# 3. ノートブックのコードの実行
# 4. 書き換えて、再実行
# 5. 白紙状態から例のプログラムの作成して実行
# 6. PDF 化して提出する方法

# %% [markdown]
# # 1.Colab ノートブックを「ドライブにコピー」
#
# 上部に「ドライブに保存」というボタンが表示されている場合は、押してください。
#
# ![スクリーンショット 2021-09-25 21.20.07.png](data:image/png;base64,...)
#
# 押すと自分の Google Drive における、Colab Notebooks というフォルダに、このノートブックが保存されます。
# ファイル名は「〜.ipynb のコピー」に変化します（末尾に「のコピー」が付加されます）。
#
# もし、「ドライブに保存」を行わずにノートブック上で作業を行うと、その結果はブラウザを閉じると消えて無くなります。

# %% [markdown]
# # 2.「Colab Notebooks」フォルダの確認
#
# Google Drive の「マイドライブ」における「Colab Notebooks」というフォルダを確認してください。
# 上で保存したファイルがあるはずです。保存日時も確認して、確かに上のファイルであることをみておきます。
#
# Google Drive:
# https://drive.google.com/

# %% [markdown]
# # 3.ノートブックのコードの実行
#
# ![コンパイルと実行.png](data:image/png;base64,...)

# %% [markdown]
# ## 3.1. コード（プログラム）例
#
# まずはこのプログラムから始めましょう。
# 簡単なプログラムについて、実行する方法を学びます。
#
# 1行目付近左側の実行ボタン▶️を押すと、`01hello.c` というファイルが作成されます。1行目はプログラムではなく、この Google Colab でプログラミングする際に特有な指示です。2 行目以下を `01hello.c` という名前で保存せよという意味になります。
#
# 実行ボタン▶️を押してください。

# %%
# %%file 01hello.c
# #include <stdio.h>
#
# int main(void)
# {
#     printf("Hello!");
#
#     return 0;
# }
# Out:
# Writing 01hello.c

# %% [markdown]
# ## 3.2. ソースコードファイルの確認
#
# 左のフォルダ（🗂）アイコンをクリックして、 `01hello.c` という名前のファイルがあることを確認しよう。
# さらにそのファイルをダブルクリックして、内容を確認してみよう。
#
# 上のセルの 2 行目以下が保存されているのが確認できると思います。
#
# ## 用語
# **ソース**（source）というのは、源とか元となるものという意味です。
# 「情報のソースはどこだ」のような使用例は聞いたことがあると思います。
# 情報のソースというのは情報源のことですね。
# ソース電流、シンク電流という用語を聞いたこともあるかもしれませんね。
#
# 実際にコンピュータが実行できるのは機械語であり、通常 2 進数や 16 進数で表されるスイッチの集まりなので、上のソースコードを機械語に変換する必要があります。
# その機械語の元となるということで「ソース」コードというわけです。
#
# **コード**（code）というのは説明不要と思いますが、体系づけられた意味を持つ記号の並びで、文脈によっては「符号」と訳されます。
# QR コードとか、バーコードとかはおなじみでしょう。
# モールスコード（モールス符号、モールス信号）も知っている人は多いのではないでしょうか。
#
# プログラミング初心者にとっては、上記のコードは記号の羅列に見えるかもしれません。これから徐々に複雑なプログラムを作成していきますが、その過程で意味的な塊が見えるようになってくると思います。まずは、それぞれの記号をおろそかにせずにひとつひとつ丁寧に見るように心がけてください。

# %% [markdown]
# ## 3.3. 上記コードの実行
#
# 上で作成した、ソースコードはそのままではコンピュータは解釈できません。
# それをコンピュータにとって、より実行しやすい形式に変換（コンパイル）する必要があります。ここで用いる C コンパイラでは、最終的に機械語（トグルスイッチだけが並んだ言語、通常 16 進数や 2 進数で表される）に変換されます。
# その変換した結果（とくにファイル名を指定しなければ `a.out` という名前のファイルが作成されるので、それを実行します。
#
# 次の実行セルの実行ボタン▶️を押してください。

# %%
! clang 01hello.c && ./a.out
# Out:
# Hello!

# %% [markdown]
# # 4.書き換えて、再実行
#
# つぎのコードセルのコード（`3.1.` のコードと同じ）の 6 行目以降を書き換えて、実行してみよう。

# %% [markdown]
# 課題
#
# 1. コード（プログラム）を書き換えて「こんにちは」と表示されるようにしてみよう。
#     * どこを書き換えたらよいか、勘を働かせてみよう。
# 2. `printf` （プリント・エフ）と書かれている行をコピーして（キーボードから打ち込んでもよい）、「こんにちは」が 2 回表示されるようにしてみよう。
# 3. `printf` の代わりに `puts` （プット・エス、あるいはプット・ストリング）と書き換えて、動作を比較してみよう。何が変わったか？
# 4. 好きな顔文字などを表示させてみよう 😁🐈🐈
#
# わけが分からなくなったら、以下のコードをコピーしてやり直してください。
#
# ```c
# #include <stdio.h>
#
# int main(void)
# {
#     printf("Hello!");
#
#     return 0;
# }
# ```

# %% [markdown]
# ソースコード（書き換えてみよ）
#
# ※ 提出するコードは動作するものにしてください。内容は上記課題にもとづいて各自工夫してください。

# %%
# %%file 01hello2.c
# #include <stdio.h>
#
# int main(void)
# {
#     printf("Hello!");
#
#     return 0;
# }

# %% [markdown]
# ソースコードのコンパイル、および実行

# %%
# !clang 01hello2.c && ./a.out

# %% [markdown]
# # 5.白紙状態から例のプログラムの作成して実行
#
#
# `Hello!` と表示するソースコードの作成
#
# （なるべく、記憶をもとに再現してみよう。思い出せない部分は `3.1.` をちらっと見てもよい。）

# %%
# %%file 01hello3.c

# %% [markdown]
# ソースコードのコンパイル、および実行

# %%
# !clang 01hello3.c && ./a.out

# %% [markdown]
# # 6.このノートブックを PDF 化して提出する方法
#
# 今回はこのノートブックを PDF に変換して提出してください。
# ブラウザの印刷機能を利用します。プリンタの一覧のなかに「PDFで保存」（あるいは類似の表記）というものがあるはずです。それを選択すると、現在閲覧のページを PDF に変換して保存できます。

# %% [markdown]
# # 宿題 1 スクリーンショット部分
#
# 宿題の説明は、授業資料（指示書）の末尾に記述しています。
#
# 指定のフォントをインストールしたあと、**このセルだけ**のスクリーンショットを提出してください（**写真不可**）。
#
# ```
# 012345678901234567890
# ^         ^         ^
# |         |         |
# abcdefghijklmnopqrstuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# あいうえおかきくけこさしす
# ```
